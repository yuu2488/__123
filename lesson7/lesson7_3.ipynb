# %%
import PIL.Image
from google import genai
from IPython.display import display, Markdown

client = genai.Client()
image = PIL.Image.open('bear.jpg')
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image, "請告訴我這是什麼動物,還有關於它的一些資訊"]
)

display(Markdown(response.text))
# Out:
# 這是一隻**棕熊 (Brown Bear)**。
#
# 棕熊是陸地上體型最大的食肉動物之一，也是分佈最廣的熊科動物。圖片中的棕熊毛色為典型的棕色，體型結實，符合其主要特徵。在北美洲，其一些亞種常被稱為**灰熊 (Grizzly Bear)**。
#
# 以下是關於棕熊的一些資訊：
#
# 1.  **分類與名稱：**
#     *   學名：*Ursus arctos*
#     *   中文名稱：棕熊，在北美洲特定亞種常被稱為灰熊。
#     *   牠們有多個亞種，分佈於世界各地，外形和體型會有差異。
#
# 2.  **外形特徵：**
#     *   **體型龐大：** 棕熊的體型因地區和亞種而異，雄性通常比雌性大。成年棕熊體重可從100公斤到超過600公斤不等（例如阿拉斯加的科迪亞克棕熊是最大的陸地食肉動物之一）。
#     *   **毛色：** 毛色多變，從淺棕色、金棕色到深棕色甚至近黑色都有。一些亞種，特別是北美灰熊，背部和肩部毛髮的尖端常有銀色或灰色的「霜狀」斑點，因此得名「Grizzly」（意為灰白的）。
#     *   **肩部隆起：** 其肩部有明顯的肌肉隆起，這是其強大前肢力量的來源，也是區分牠們與美洲黑熊的一個重要特徵。
#     *   **爪子：** 擁有長而彎曲的非伸縮性爪子，非常適合挖掘洞穴、尋找食物和捕魚。
#
# 3.  **分佈與棲息地：**
#     *   棕熊廣泛分佈於北半球，包括北美洲（加拿大、美國阿拉斯加和部分美國西部地區）、歐洲（尤其在東歐和北歐）和亞洲（俄羅斯、中國、日本北海道等地）。
#     *   牠們能適應多種環境，包括森林、山區、苔原、海岸線和草地。
#
# 4.  **食性：**
#     *   棕熊是雜食性動物，食譜非常廣泛。
#     *   牠們會吃漿果、根莖、堅果、昆蟲、魚類（尤其是鮭魚）、小型哺乳動物、腐肉，有時也會捕食大型有蹄類動物（如鹿、麋鹿）。
#
# 5.  **行為特徵：**
#     *   **獨居：** 通常是獨居動物，只有在繁殖期或母熊帶幼崽時才會有家庭單元。
#     *   **冬眠：** 在寒冷的冬季會進入冬眠狀態，在洞穴中度過數月，期間不進食、不排泄。
#     *   **感官：** 嗅覺極其靈敏，是牠們尋找食物和感知環境的主要方式。聽覺和視覺也很好。
#     *   **力量與速度：** 雖然體型龐大，但棕熊可以跑得非常快（短距離可達50公里/小時），也是優秀的游泳者。
#
# 6.  **與人類的關係：**
#     *   棕熊通常會避開人類，但如果感到威脅（尤其是有幼崽的母熊）、受到挑釁或被食物吸引時，牠們可能會變得具有攻擊性。
#     *   因此，在棕熊棲息地活動時，務必保持警惕並遵循國家公園或當地發布的安全準則。
#
# 7.  **保護狀況：**
#     *   儘管全球範圍內棕熊的總體數量被列為「無危」，但某些地區的亞種數量仍面臨棲息地喪失、碎片化和偷獵的威脅，並受到當地法律的保護。
#
# 總而言之，棕熊是一種令人敬畏的野生動物，其強大的適應能力和雜食性使其能在多樣的環境中生存。
